# %% [markdown]
# # 02 — Service métier avec fakes
#
# Ce checkpoint rejoue les tests du service sans PostgreSQL ni appel réseau.

# %%
import sys
from pathlib import Path

print(sys.executable)
assert Path("pyproject.toml").exists(), "Ouvrir le notebook depuis la racine du dépôt"

# %%
import pytest

exit_code = pytest.main(["tests/unit/test_service.py", "-q"])
assert exit_code == pytest.ExitCode.OK
