# %% [markdown]
# # 06 — Human-in-the-loop hors ligne
#
# Le modèle scripté prouve que refus = zéro écriture et approbation = une écriture.

# %%
import pytest

exit_code = pytest.main(["tests/agent/test_hitl.py", "-q"])
assert exit_code == pytest.ExitCode.OK
